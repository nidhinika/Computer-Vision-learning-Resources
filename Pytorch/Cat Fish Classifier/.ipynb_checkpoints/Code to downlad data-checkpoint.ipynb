# %% [markdown]
# ## Code to download data

# %%
! pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zuraiz/fish-vs-cats-imagenet-subdataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/zuraiz/fish-vs-cats-imagenet-subdataset?dataset_version_number=2...
# 100%|█████████████████████████████████████████████████████████████████████████████| 67.7M/67.7M [00:08<00:00, 8.24MB/s]
# Extracting files...
# Path to dataset files: C:\Users\OM PRAKASH LAL\.cache\kagglehub\datasets\zuraiz\fish-vs-cats-imagenet-subdataset\versions\2

# %%
mv  "C:\Users\OM PRAKASH LAL\.cache\kagglehub\datasets\zuraiz\fish-vs-cats-imagenet-subdataset\versions\2" .
